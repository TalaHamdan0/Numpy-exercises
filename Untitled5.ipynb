# %%
# ewb scraping
import requests 
from bs4  import BeautifulSoup
ur1="http://www.imdb.com/chart/top/"
headers={"user-agent":"mozilla/5.0 (windows nt 10.0;win64;) applewebkit/537.36(khtml,like gecko) chrome/122.0.0.0safari/537.36"}
response = requests.get(ur1,headers=headers)
soup =BeautifulSoup(response.text,"html.parser")

movies=soup.select("td.titlecolumn a")
for movie in movies[:10]:
    print(movie.text)
# Out:
# ---------------------------------------------------------------------------
# JsException                               Traceback (most recent call last)
# File /lib/python3.12/site-packages/urllib3/contrib/emscripten/fetch.py:664, in _run_sync_with_timeout(promise, timeout, js_abort_controller, request, response)
#     662     # run_sync here uses WebAssembly JavaScript Promise Integration to
#     663     # suspend python until the JavaScript promise resolves.
# --> 664     return run_sync(promise)
#     665 except JsException as err:
#
# JsException: TypeError: Failed to fetch
#
# During handling of the above exception, another exception occurred:
#
# _RequestError                             Traceback (most recent call last)
# File /lib/python3.12/site-packages/urllib3/contrib/emscripten/connection.py:116, in EmscriptenHTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     115 if not preload_content:
# ...

# %%
import requests
from bs4 import beautifulsoup

ur1="http://www.bbc.com/news
headers={{"user-agent":"mozilla/5.0 (windows nt 10.0;win64;) applewebkit/537.36(khtml,like gecko) chrome/122.0.0.0safari/537.36"}
respons=request.get(ur1,headers=headers)
soup=beautifulsoup(response.text,"html,parser")
news=soup.select("he a")
 for news in news([:10]):
print(news.text.strip())
# Out:
#   Cell In[6], line 4
#     ur1="http://www.bbc.com/news
#         ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
import reauests
from bs4 import beautifilsoup

ur1="http://www.bbc.com/news"
response=requests.get(ur1)
soup=beautifulsoup(response.text,"html,parser")
headline=soup.select("h3 a")                   
 for headlines in headline([:5]):
     print(headline['herf'])
# Out:
#   Cell In[7], line 8
#     for headlines in headline([:5]):
#     ^
# IndentationError: unexpected indent

# %%
import requeste
import pandas as pd
from bs4 import beautifulsoup

ur1="http://www.worldmeters.com"
header={"user-agent":"mozilla/5.0"}
response=requests.get(ur1,headers=headers)
soup=beautifulsoup(response.text,"html,praser")

table=soup.find("table",id="example2")
countries[]
population[]
for row in table.tbody.find_all("tr"):
    cols=row.find_all("td")
    countries.append(cols[1].text.strip())
    population.append(cols[2].text.strip())
    
df=pd.dataframe({"country":countries,"population":population})
df.to_csv("population.csv",index=false)
print(df.head())
